# %%
import json
from opencc import OpenCC
cc = OpenCC('s2t')
texts = []

for ABC in range(0,4):
    foldName = ''
    if ABC == 0:
        foldName = 'AA'
    elif ABC == 1:
        foldName = 'AB'
    elif ABC == 2:
        foldName = 'AC'
    elif ABC == 3:
        foldName = 'AD'        
        
    for i in range(0,99):
        fileName = ''
        if i < 10:
            fileName = './wiki_zh/'+ foldName +'/wiki_0'+str(i)
        else:
            fileName = './wiki_zh/'+ foldName +'/wiki_'+str(i)


        file = open(fileName, 'r', encoding='utf-8')
        datas = []
        for line in file.readlines():
            dic = json.loads(line)
            datas.append(dic)

        for data in datas:
            texts.append(cc.convert(data['text']))
for ABC in range(0,4):
    foldName = ''
    if ABC == 0:
        foldName = 'AE'
    elif ABC == 1:
        foldName = 'AF'
    elif ABC == 2:
        foldName = 'AG'
    elif ABC == 3:
        foldName = 'AH'        
        
    for i in range(0,99):
        fileName = ''
        if i < 10:
            fileName = './wiki_zh/'+ foldName +'/wiki_0'+str(i)
        else:
            fileName = './wiki_zh/'+ foldName +'/wiki_'+str(i)


        file = open(fileName, 'r', encoding='utf-8')
        datas = []
        for line in file.readlines():
            dic = json.loads(line)
            datas.append(dic)

        for data in datas:
            texts.append(cc.convert(data['text']))

# %%
for ABC in range(0,4):
    foldName = ''
    if ABC == 0:
        foldName = 'AI'
    elif ABC == 1:
        foldName = 'AJ'
    elif ABC == 2:
        foldName = 'AK'
    elif ABC == 3:
        foldName = 'AL'        
        
    for i in range(0,99):
        fileName = ''
        if i < 10:
            fileName = './wiki_zh/'+ foldName +'/wiki_0'+str(i)
        else:
            fileName = './wiki_zh/'+ foldName +'/wiki_'+str(i)


        file = open(fileName, 'r', encoding='utf-8')
        datas = []
        for line in file.readlines():
            dic = json.loads(line)
            datas.append(dic)

        for data in datas:
            texts.append(cc.convert(data['text']))
for i in range(0,74):
    fileName = ''
    if i < 10:
        fileName = './wiki_zh/AM/wiki_0'+str(i)
    else:
        fileName = './wiki_zh/AM/wiki_'+str(i)


    file = open(fileName, 'r', encoding='utf-8')
    datas = []
    for line in file.readlines():
        dic = json.loads(line)
        datas.append(dic)

    for data in datas:
        texts.append(cc.convert(data['text']))

# %%
import jieba

jieba.set_dictionary('dict.txt')
jiebaTexts = []


with open('wiki_text_seg.txt', 'w', encoding='utf-8') as new_f:
    for text in texts:
        stopwords = {}.fromkeys(['\n','。','(',')','"','、','，','（','）','“','”','《','》',"'",'」','「',';','：','；','…','－','—',',','·'])

        segs = ' '.join(jieba.cut(text, cut_all=False, HMM=True))
        jiebaText = ''
        for seg in segs:
            if seg not in stopwords:
                jiebaText = jiebaText + seg

        jiebaTexts.append(jiebaText)
        new_f.write(jiebaText)
# Out:
# Building prefix dict from C:\Users\Alex\dict.txt ...
# Loading model from cache C:\Users\Alex\AppData\Local\Temp\jieba.ue06a7f8ae4beec3dff98ee7d2695c488.cache
# Loading model cost 1.029 seconds.
# Prefix dict has been built successfully.

# %%
from gensim.models import word2vec

# Settings
seed = 666
sg = 0
window_size = 10
vector_size = 100
min_count = 1
workers = 8
epochs = 5
batch_words = 10000

train_data = word2vec.LineSentence('wiki_text_seg.txt')
model = word2vec.Word2Vec(
    train_data,
    min_count=min_count,
    vector_size=vector_size,
    workers=workers,
    epochs=epochs,
    window=window_size,
    sg=sg,
    seed=seed,
    batch_words=batch_words
)

model.save('word2vec.model')
# Out:
# D:\Anaconda\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# # 測試

# %%
from gensim.models import word2vec
import numpy as np

model = word2vec.Word2Vec.load('word2vec.model')
#print(model.wv['Linux'].shape)#維度

# Zero padding
padding = np.zeros((model.vector_size,), dtype=np.float32)


# Error process
try:
    print(model.wv["taiwan"].shape)
    for item in model.wv.most_similar('taiwan',topn= 20):
        print(item)    
except:
    print("此字詞未在字典中")
    print(padding.shape)
# Out:
# (100,)
# ('페', 0.7374466061592102)
# ('샤', 0.7078522443771362)
# ('잘', 0.7055301666259766)
# ('않', 0.6971635222434998)
# ('언', 0.6953119039535522)
# ('全炫茂', 0.6919234991073608)
# ('되', 0.6915711760520935)
# ('쿵', 0.6909729242324829)
# ('브', 0.6898466944694519)
# ('션', 0.6895772218704224)
# ('entertainment', 0.6863951086997986)
# ('걸', 0.6835567355155945)
# ('華莎', 0.6827865242958069)
# ('GOTTA', 0.6821539998054504)
# ('玄院', 0.6808730363845825)
# ('CULTURE', 0.6795862913131714)
# ('定杆', 0.6784536838531494)
# ('hinet', 0.6777432560920715)
# ('겠', 0.677249550819397)
# ('孫建波', 0.6754023432731628)
