# %%
import json
from opencc import OpenCC
cc = OpenCC('s2t')
texts = []

for ABC in range(0,4):
    foldName = ''
    if ABC == 0:
        foldName = 'AA'
    elif ABC == 1:
        foldName = 'AB'
    elif ABC == 2:
        foldName = 'AC'
    elif ABC == 3:
        foldName = 'AD'        
        
    for i in range(0,99):
        fileName = ''
        if i < 10:
            fileName = './wiki_zh/'+ foldName +'/wiki_0'+str(i)
        else:
            fileName = './wiki_zh/'+ foldName +'/wiki_'+str(i)


        file = open(fileName, 'r', encoding='utf-8')
        datas = []
        for line in file.readlines():
            dic = json.loads(line)
            datas.append(dic)

        for data in datas:
            texts.append(cc.convert(data['text']))
for ABC in range(0,4):
    foldName = ''
    if ABC == 0:
        foldName = 'AE'
    elif ABC == 1:
        foldName = 'AF'
    elif ABC == 2:
        foldName = 'AG'
    elif ABC == 3:
        foldName = 'AH'        
        
    for i in range(0,99):
        fileName = ''
        if i < 10:
            fileName = './wiki_zh/'+ foldName +'/wiki_0'+str(i)
        else:
            fileName = './wiki_zh/'+ foldName +'/wiki_'+str(i)


        file = open(fileName, 'r', encoding='utf-8')
        datas = []
        for line in file.readlines():
            dic = json.loads(line)
            datas.append(dic)

        for data in datas:
            texts.append(cc.convert(data['text']))

# %%
for ABC in range(0,4):
    foldName = ''
    if ABC == 0:
        foldName = 'AI'
    elif ABC == 1:
        foldName = 'AJ'
    elif ABC == 2:
        foldName = 'AK'
    elif ABC == 3:
        foldName = 'AL'        
        
    for i in range(0,99):
        fileName = ''
        if i < 10:
            fileName = './wiki_zh/'+ foldName +'/wiki_0'+str(i)
        else:
            fileName = './wiki_zh/'+ foldName +'/wiki_'+str(i)


        file = open(fileName, 'r', encoding='utf-8')
        datas = []
        for line in file.readlines():
            dic = json.loads(line)
            datas.append(dic)

        for data in datas:
            texts.append(cc.convert(data['text']))
for i in range(0,74):
    fileName = ''
    if i < 10:
        fileName = './wiki_zh/AM/wiki_0'+str(i)
    else:
        fileName = './wiki_zh/AM/wiki_'+str(i)


    file = open(fileName, 'r', encoding='utf-8')
    datas = []
    for line in file.readlines():
        dic = json.loads(line)
        datas.append(dic)

    for data in datas:
        texts.append(cc.convert(data['text']))

# %%
import jieba

jieba.set_dictionary('dict.txt')
jiebaTexts = []


with open('wiki_text_seg.txt', 'w', encoding='utf-8') as new_f:
    for text in texts:
        stopwords = {}.fromkeys(['\n','。','(',')','"','、','，','（','）','“','”','《','》',"'",'」','「',';','：','；','…','－','—',',','·'])

        segs = ' '.join(jieba.cut(text, cut_all=False, HMM=True))
        jiebaText = ''
        for seg in segs:
            if seg not in stopwords:
                jiebaText = jiebaText + seg

        jiebaTexts.append(jiebaText)
        new_f.write(jiebaText)
# Out:
# Building prefix dict from C:\Users\Alex\dict.txt ...
# Loading model from cache C:\Users\Alex\AppData\Local\Temp\jieba.ue06a7f8ae4beec3dff98ee7d2695c488.cache
# Loading model cost 1.029 seconds.
# Prefix dict has been built successfully.

# %%
from gensim.models import word2vec

# Settings
seed = 666
sg = 0
window_size = 10
vector_size = 100
min_count = 1
workers = 8
epochs = 5
batch_words = 10000

train_data = word2vec.LineSentence('wiki_text_seg.txt')
model = word2vec.Word2Vec(
    train_data,
    min_count=min_count,
    vector_size=vector_size,
    workers=workers,
    epochs=epochs,
    window=window_size,
    sg=sg,
    seed=seed,
    batch_words=batch_words
)

model.save('word2vec.model')
# Out:
# D:\Anaconda\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# # 測試

# %%
from gensim.models import word2vec
import numpy as np

model = word2vec.Word2Vec.load('word2vec.model')
#print(model.wv['Linux'].shape)#維度

# Zero padding
padding = np.zeros((model.vector_size,), dtype=np.float32)


# Error process
try:
    print(model.wv["國家"].shape)
    for item in model.wv.most_similar('國家',topn= 20):
        print(item)    
except:
    print("not found in Word2Vec model!")
    print(padding.shape)
# Out:
# (100,)
# ('成員國', 0.7511151432991028)
# ('第三世界', 0.6787367463111877)
# ('會員國', 0.6691936254501343)
# ('歐洲聯盟', 0.665164589881897)
# ('發展中國家', 0.6597890257835388)
# ('歐盟', 0.6497278213500977)
# ('主權國家', 0.649399995803833)
# ('機構', 0.6420654654502869)
# ('經濟體', 0.6386934518814087)
# ('獨聯體', 0.6367732882499695)
# ('歐洲', 0.6291713714599609)
# ('西歐國家', 0.6244255900382996)
# ('國內', 0.6230842471122742)
# ('發達國家', 0.6164244413375854)
# ('各國', 0.6153854131698608)
# ('東歐國家', 0.6150026321411133)
# ('本國', 0.6124219298362732)
# ('東方集團', 0.5972055792808533)
# ('聯合國', 0.5959557890892029)
# ('歐元區', 0.5952706933021545)
