# %%
import json
from opencc import OpenCC
cc = OpenCC('s2t')
texts = []

for ABC in range(0,4):
    foldName = ''
    if ABC == 0:
        foldName = 'AA'
    elif ABC == 1:
        foldName = 'AB'
    elif ABC == 2:
        foldName = 'AC'
    elif ABC == 3:
        foldName = 'AD'        
        
    for i in range(0,99):
        fileName = ''
        if i < 10:
            fileName = './wiki_zh/'+ foldName +'/wiki_0'+str(i)
        else:
            fileName = './wiki_zh/'+ foldName +'/wiki_'+str(i)


        file = open(fileName, 'r', encoding='utf-8')
        datas = []
        for line in file.readlines():
            dic = json.loads(line)
            datas.append(dic)

        for data in datas:
            texts.append(cc.convert(data['text']))
for ABC in range(0,4):
    foldName = ''
    if ABC == 0:
        foldName = 'AE'
    elif ABC == 1:
        foldName = 'AF'
    elif ABC == 2:
        foldName = 'AG'
    elif ABC == 3:
        foldName = 'AH'        
        
    for i in range(0,99):
        fileName = ''
        if i < 10:
            fileName = './wiki_zh/'+ foldName +'/wiki_0'+str(i)
        else:
            fileName = './wiki_zh/'+ foldName +'/wiki_'+str(i)


        file = open(fileName, 'r', encoding='utf-8')
        datas = []
        for line in file.readlines():
            dic = json.loads(line)
            datas.append(dic)

        for data in datas:
            texts.append(cc.convert(data['text']))

# %%
for ABC in range(0,4):
    foldName = ''
    if ABC == 0:
        foldName = 'AI'
    elif ABC == 1:
        foldName = 'AJ'
    elif ABC == 2:
        foldName = 'AK'
    elif ABC == 3:
        foldName = 'AL'        
        
    for i in range(0,99):
        fileName = ''
        if i < 10:
            fileName = './wiki_zh/'+ foldName +'/wiki_0'+str(i)
        else:
            fileName = './wiki_zh/'+ foldName +'/wiki_'+str(i)


        file = open(fileName, 'r', encoding='utf-8')
        datas = []
        for line in file.readlines():
            dic = json.loads(line)
            datas.append(dic)

        for data in datas:
            texts.append(cc.convert(data['text']))
for i in range(0,74):
    fileName = ''
    if i < 10:
        fileName = './wiki_zh/AM/wiki_0'+str(i)
    else:
        fileName = './wiki_zh/AM/wiki_'+str(i)


    file = open(fileName, 'r', encoding='utf-8')
    datas = []
    for line in file.readlines():
        dic = json.loads(line)
        datas.append(dic)

    for data in datas:
        texts.append(cc.convert(data['text']))

# %%
import jieba

jieba.set_dictionary('dict.txt')
jiebaTexts = []


with open('wiki_text_seg.txt', 'w', encoding='utf-8') as new_f:
    for text in texts:
        stopwords = {}.fromkeys(['\n','。','(',')','"','、','，','（','）','“','”','《','》',"'",'」','「',';','：','；','…','－','—',',','·'])

        segs = ' '.join(jieba.cut(text, cut_all=False, HMM=True))
        jiebaText = ''
        for seg in segs:
            if seg not in stopwords:
                jiebaText = jiebaText + seg

        jiebaTexts.append(jiebaText)
        new_f.write(jiebaText)
# Out:
# Building prefix dict from C:\Users\Alex\dict.txt ...
# Loading model from cache C:\Users\Alex\AppData\Local\Temp\jieba.ue06a7f8ae4beec3dff98ee7d2695c488.cache
# Loading model cost 1.029 seconds.
# Prefix dict has been built successfully.

# %%
from gensim.models import word2vec

# Settings
seed = 666
sg = 0
window_size = 10
vector_size = 100
min_count = 1
workers = 8
epochs = 5
batch_words = 10000

train_data = word2vec.LineSentence('wiki_text_seg.txt')
model = word2vec.Word2Vec(
    train_data,
    min_count=min_count,
    vector_size=vector_size,
    workers=workers,
    epochs=epochs,
    window=window_size,
    sg=sg,
    seed=seed,
    batch_words=batch_words
)

model.save('word2vec.model')
# Out:
# D:\Anaconda\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# # 測試

# %%
from gensim.models import word2vec
import numpy as np

model = word2vec.Word2Vec.load('word2vec.model')
#print(model.wv['Linux'].shape)#維度

# Zero padding
padding = np.zeros((model.vector_size,), dtype=np.float32)


# Error process
try:
    print(model.wv["momo"].shape)
    for item in model.wv.most_similar('momo',topn= 20):
        print(item)    
except:
    print("此字詞未在字典中")
    print(padding.shape)
# Out:
# (100,)
# ('韓宜邦', 0.7458797693252563)
# ('楊慶煌', 0.7378942370414734)
# ('潘傑寧', 0.7362285256385803)
# ('TenTenClub', 0.7342265844345093)
# ('郭靜純', 0.7327559590339661)
# ('劉一樂', 0.7327018976211548)
# ('錄留', 0.7287868857383728)
# ('貝登及', 0.7276427745819092)
# ('Polimonitor', 0.7273988127708435)
# ('胡麗明', 0.7240361571311951)
# ('薛安都則', 0.7229148745536804)
# ('小黎', 0.7226687073707581)
# ('Midsar', 0.7220928072929382)
# ('尹昭德', 0.7212777733802795)
# ('Sori', 0.7208406925201416)
# ('採訊', 0.7207496166229248)
# ('夏靖庭', 0.719892680644989)
# ('Lidea', 0.718669593334198)
# ('由緯來', 0.7185189127922058)
# ('俽', 0.7180147171020508)
