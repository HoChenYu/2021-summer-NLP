# %%
import json
from opencc import OpenCC
cc = OpenCC('s2t')
texts = []

for ABC in range(0,4):
    foldName = ''
    if ABC == 0:
        foldName = 'AA'
    elif ABC == 1:
        foldName = 'AB'
    elif ABC == 2:
        foldName = 'AC'
    elif ABC == 3:
        foldName = 'AD'        
        
    for i in range(0,99):
        fileName = ''
        if i < 10:
            fileName = './wiki_zh/'+ foldName +'/wiki_0'+str(i)
        else:
            fileName = './wiki_zh/'+ foldName +'/wiki_'+str(i)


        file = open(fileName, 'r', encoding='utf-8')
        datas = []
        for line in file.readlines():
            dic = json.loads(line)
            datas.append(dic)

        for data in datas:
            texts.append(cc.convert(data['text']))
for ABC in range(0,4):
    foldName = ''
    if ABC == 0:
        foldName = 'AE'
    elif ABC == 1:
        foldName = 'AF'
    elif ABC == 2:
        foldName = 'AG'
    elif ABC == 3:
        foldName = 'AH'        
        
    for i in range(0,99):
        fileName = ''
        if i < 10:
            fileName = './wiki_zh/'+ foldName +'/wiki_0'+str(i)
        else:
            fileName = './wiki_zh/'+ foldName +'/wiki_'+str(i)


        file = open(fileName, 'r', encoding='utf-8')
        datas = []
        for line in file.readlines():
            dic = json.loads(line)
            datas.append(dic)

        for data in datas:
            texts.append(cc.convert(data['text']))

# %%
for ABC in range(0,4):
    foldName = ''
    if ABC == 0:
        foldName = 'AI'
    elif ABC == 1:
        foldName = 'AJ'
    elif ABC == 2:
        foldName = 'AK'
    elif ABC == 3:
        foldName = 'AL'        
        
    for i in range(0,99):
        fileName = ''
        if i < 10:
            fileName = './wiki_zh/'+ foldName +'/wiki_0'+str(i)
        else:
            fileName = './wiki_zh/'+ foldName +'/wiki_'+str(i)


        file = open(fileName, 'r', encoding='utf-8')
        datas = []
        for line in file.readlines():
            dic = json.loads(line)
            datas.append(dic)

        for data in datas:
            texts.append(cc.convert(data['text']))
for i in range(0,74):
    fileName = ''
    if i < 10:
        fileName = './wiki_zh/AM/wiki_0'+str(i)
    else:
        fileName = './wiki_zh/AM/wiki_'+str(i)


    file = open(fileName, 'r', encoding='utf-8')
    datas = []
    for line in file.readlines():
        dic = json.loads(line)
        datas.append(dic)

    for data in datas:
        texts.append(cc.convert(data['text']))

# %%
import jieba

jieba.set_dictionary('dict.txt')
jiebaTexts = []


with open('wiki_text_seg.txt', 'w', encoding='utf-8') as new_f:
    for text in texts:
        stopwords = {}.fromkeys(['\n','。','(',')','"','、','，','（','）','“','”','《','》',"'",'」','「',';','：','；','…','－','—',',','·'])

        segs = ' '.join(jieba.cut(text, cut_all=False, HMM=True))
        jiebaText = ''
        for seg in segs:
            if seg not in stopwords:
                jiebaText = jiebaText + seg

        jiebaTexts.append(jiebaText)
        new_f.write(jiebaText)
# Out:
# Building prefix dict from C:\Users\Alex\dict.txt ...
# Loading model from cache C:\Users\Alex\AppData\Local\Temp\jieba.ue06a7f8ae4beec3dff98ee7d2695c488.cache
# Loading model cost 1.029 seconds.
# Prefix dict has been built successfully.

# %%
from gensim.models import word2vec

# Settings
seed = 666
sg = 0
window_size = 10
vector_size = 100
min_count = 1
workers = 8
epochs = 5
batch_words = 10000

train_data = word2vec.LineSentence('wiki_text_seg.txt')
model = word2vec.Word2Vec(
    train_data,
    min_count=min_count,
    vector_size=vector_size,
    workers=workers,
    epochs=epochs,
    window=window_size,
    sg=sg,
    seed=seed,
    batch_words=batch_words
)

model.save('word2vec.model')
# Out:
# D:\Anaconda\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# # 測試

# %%
from gensim.models import word2vec
import numpy as np

model = word2vec.Word2Vec.load('word2vec.model')
#print(model.wv['Linux'].shape)#維度

# Zero padding
padding = np.zeros((model.vector_size,), dtype=np.float32)


# Error process
try:
    print(model.wv["twice"].shape)
    for item in model.wv.most_similar('twice',topn= 20):
        print(item)    
except:
    print("此字詞未在字典中")
    print(padding.shape)
# Out:
# (100,)
# ('final', 0.7841532826423645)
# ('making', 0.7841067910194397)
# ('five', 0.7808284759521484)
# ('every', 0.7761571407318115)
# ('six', 0.7740426659584045)
# ('four', 0.7696062922477722)
# ('clarify', 0.7688940763473511)
# ('two', 0.7675609588623047)
# ('runway', 0.7628955841064453)
# ('after', 0.7626469135284424)
# ('goal', 0.7622253894805908)
# ('match', 0.761803925037384)
# ('reached', 0.76113361120224)
# ('around', 0.760936975479126)
# ('obstructing', 0.759490430355072)
# ('fourth', 0.7591807246208191)
# ('uniforms', 0.7581477761268616)
# ('because', 0.7571804523468018)
# ('teams', 0.7567669153213501)
# ('third', 0.7538059949874878)
